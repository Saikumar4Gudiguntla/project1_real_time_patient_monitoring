# %%
import pandas as pd
import numpy as np

from pathlib import Path

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 140)

# %%
Path.cwd()
# Out:
# PosixPath('/Users/saig/project1_real_time_patient_monitoring/anaconda_projects/181246e5-d2b4-48d2-981a-8e6bdbfe6b66')

# %%
Path.cwd().rglob("dailyActivity_merged.csv")
# Out:
# <generator object Path.rglob at 0x12179f230>

# %%
list(Path.cwd().rglob("dailyActivity_merged.csv"))
# Out:
# []

# %%
for p in Path.cwd().rglob("dailyActivity_merged.csv"):
    print(p)

# %%
from pathlib import Path
import pandas as pd

# 1) Set PROJECT_ROOT to the folder that contains "data"
# If your notebook is inside "notebooks/", this will likely be one level up.
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent  # go up one level

RAW_PATH = PROJECT_ROOT / "data" / "raw"
print("PROJECT_ROOT:", PROJECT_ROOT)
print("RAW_PATH:", RAW_PATH)
print("Files in raw:", [p.name for p in RAW_PATH.glob("*")])
# Out:
# PROJECT_ROOT: /Users/saig/project1_real_time_patient_monitoring/anaconda_projects
# RAW_PATH: /Users/saig/project1_real_time_patient_monitoring/anaconda_projects/data/raw
# Files in raw: []

# %%
file_name = "dailyActivity_merged.csv"
file_path = RAW_PATH / file_name

df = pd.read_csv(file_path)
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 4
#       1 file_name = "dailyActivity_merged.csv"
#       2 file_path = RAW_PATH / file_name
# ----> 4 df = pd.read_csv(file_path)
#       5 print(df.shape)
#       6 df.head()
#
# ...
